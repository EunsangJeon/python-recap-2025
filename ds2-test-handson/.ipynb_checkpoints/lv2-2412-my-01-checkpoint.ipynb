# %%
import pandas as pd

# %%
WASHER = pd.read_csv('lv2-2412.csv')

# %%
WASHER.shape
# Out:
# (205, 9)

# %%
WASHER.head()
# Out:
#    PRD_ID  WEIGHT  ENERGY_CONS  WATER_CONS  SPIN_SPEED  NOISE MOTOR_TYPE  \
# 0       1  251.35       209.10       26.55     1238.97  79.68          A
# 1       2  250.84       208.93       29.32     1240.25  81.78          A
# 2       3  254.01       215.46       29.28     1351.34  68.60          A
# 3       4  258.55       206.91       25.93     1344.86  77.76          B
# 4       5  258.56       207.93       26.26     1343.22  76.79          C
#
#   MATERIAL  SCORE
# 0        A     68
# 1        A     75
# 2        A     72
# 3        B     71
# 4        B     75

# %% [markdown]
# # Q1

# %%
df_1 = WASHER.copy()

# %% [markdown]
# # 1-1

# %%
DF40_A = df_1[df_1['MOTOR_TYPE'] == 'A']

# %%
DF40_B = df_1[df_1['MOTOR_TYPE'] == 'B']

# %% [markdown]
# # 1-2

# %%
targets = ['ENERGY_CONS', 'WATER_CONS', 'NOISE']

# %%
COR_A = []
COR_B = []

# %%
from scipy.stats import pearsonr

# %%
for target in targets:
    p_a = pearsonr(x=DF40_A[target], y=DF40_A['SCORE'])
    COR_A.append(p_a[0])
    p_b = pearsonr(x=DF40_B[target], y=DF40_B['SCORE'])
    COR_B.append(p_b[0])

# %% [markdown]
# # 1-3

# %%
COR_A
# Out:
# [np.float64(0.6664521262737249),
#  np.float64(0.5167342347211216),
#  np.float64(0.3721840631868748)]

# %%
COR_B
# Out:
# [np.float64(0.6602443967298892),
#  np.float64(0.17874088955641126),
#  np.float64(0.20501187669651982)]

# %%
GAP = []

for i in range(3):
    GAP.append(abs(COR_A[i] - COR_B[i]))

# %%
GAP
# Out:
# [np.float64(0.006207729543835638),
#  np.float64(0.3379933451647103),
#  np.float64(0.16717218649035498)]

# %%
SUM = 0

for i in range(3):
    SUM += GAP[i]

# %%
SUM
# Out:
# np.float64(0.5113732611989009)

# %% [markdown]
# # Q1 Answer

# %%
print(round(SUM, 3))
# Out:
# 0.511

# %% [markdown]
# # Q2

# %% [markdown]
# # 2-1

# %%
df_2 = WASHER.copy()

# %%
df_2.shape
# Out:
# (205, 9)

# %%
df_2.columns
# Out:
# Index(['PRD_ID', 'WEIGHT', 'ENERGY_CONS', 'WATER_CONS', 'SPIN_SPEED', 'NOISE',
#        'MOTOR_TYPE', 'MATERIAL', 'SCORE'],
#       dtype='object')

# %%
targets = [ 'WEIGHT', 'ENERGY_CONS', 'WATER_CONS', 'SPIN_SPEED', 'NOISE']

# %%
from sklearn.preprocessing import StandardScaler

# %%
for target in targets:
    df_2[target + '_S'] = StandardScaler().fit_transform(X=df_2.loc[:, [target]])

# %%
df_2.head()
# Out:
#    PRD_ID  WEIGHT  ENERGY_CONS  WATER_CONS  SPIN_SPEED  NOISE MOTOR_TYPE  \
# 0       1  251.35       209.10       26.55     1238.97  79.68          A
# 1       2  250.84       208.93       29.32     1240.25  81.78          A
# 2       3  254.01       215.46       29.28     1351.34  68.60          A
# 3       4  258.55       206.91       25.93     1344.86  77.76          B
# 4       5  258.56       207.93       26.26     1343.22  76.79          C
#
#   MATERIAL  SCORE  WEIGHT_S  ENERGY_CONS_S  WATER_CONS_S  SPIN_SPEED_S  \
# 0        A     68 -0.306208       0.262800     -0.914288     -1.852161
# 1        A     75 -0.355352       0.234060      0.626713     -1.823603
# 2        A     72 -0.049891       1.338015      0.604460      0.654864
# 3        B     71  0.387583      -0.107439     -1.259206      0.510292
# 4        B     75  0.388546       0.065001     -1.075621      0.473703
#
#     NOISE_S
# 0  0.543525
# 1  1.193455
# 2 -2.885626
# 3 -0.050696
# 4 -0.350901

# %% [markdown]
# # 2-2

# %%
tmp = []

for target in targets:
    tmp.append(target + '_S')

# %%
targets = tmp

# %%
targets
# Out:
# ['WEIGHT_S', 'ENERGY_CONS_S', 'WATER_CONS_S', 'SPIN_SPEED_S', 'NOISE_S']

# %%
from sklearn.cluster import KMeans

# %%
model = KMeans(n_clusters=3, random_state=1234).fit(X=df_2.loc[:, targets])

# %% [markdown]
# # 2-3

# %%
df_2['LABEL'] = model.predict(X=df_2.loc[:, targets])

# %%
summary = df_2.groupby('LABEL')['SCORE'].mean().reset_index()

# %%
summary
# Out:
#    LABEL      SCORE
# 0      0  65.611111
# 1      1  76.910256
# 2      2  67.789474

# %%
summary['SCORE'].max()
# Out:
# np.float64(76.91025641025641)

# %% [markdown]
# # Q2 Answer

# %%
print(round(summary['SCORE'].max(), 2))
# Out:
# 76.91

# %% [markdown]
# # Q3

# %%
df_3 = WASHER.copy()

# %% [markdown]
# # 3-1

# %%
targets = ['MOTOR_TYPE', 'MATERIAL']

# %%
df_3 = pd.get_dummies(df_3, columns=targets, drop_first=True)

# %%
df_3.head()
# Out:
#    PRD_ID  WEIGHT  ENERGY_CONS  WATER_CONS  SPIN_SPEED  NOISE  SCORE  \
# 0       1  251.35       209.10       26.55     1238.97  79.68     68
# 1       2  250.84       208.93       29.32     1240.25  81.78     75
# 2       3  254.01       215.46       29.28     1351.34  68.60     72
# 3       4  258.55       206.91       25.93     1344.86  77.76     71
# 4       5  258.56       207.93       26.26     1343.22  76.79     75
#
#    MOTOR_TYPE_B  MOTOR_TYPE_C  MATERIAL_B
# 0         False         False       False
# 1         False         False       False
# 2         False         False       False
# 3          True         False        True
# 4         False          True        True

# %% [markdown]
# # 3-2

# %%
TRAIN26 = df_3[df_3['PRD_ID'] % 5 != 0]
TEST26 = df_3[df_3['PRD_ID'] % 5 == 0]

# %%
TRAIN26.shape
# Out:
# (164, 10)

# %%
TEST26.shape
# Out:
# (41, 10)

# %% [markdown]
# # 3-3

# %%
from sklearn.linear_model import LinearRegression

# %%
TRAIN26.columns
# Out:
# Index(['PRD_ID', 'WEIGHT', 'ENERGY_CONS', 'WATER_CONS', 'SPIN_SPEED', 'NOISE',
#        'SCORE', 'MOTOR_TYPE_B', 'MOTOR_TYPE_C', 'MATERIAL_B'],
#       dtype='object')

# %%
targets = ['WEIGHT', 'ENERGY_CONS', 'WATER_CONS', 'SPIN_SPEED', 'NOISE', 'MOTOR_TYPE_B', 'MOTOR_TYPE_C', 'MATERIAL_B']

# %%
len(targets)
# Out:
# 8

# %%
model = LinearRegression().fit(y=TRAIN26['SCORE'], X=TRAIN26.loc[:, targets])

# %% [markdown]
# # 3-4

# %%
pred = model.predict(X=TEST26.loc[:, targets])

# %%
from sklearn.metrics import mean_squared_error

# %%
mse = mean_squared_error(y_true=TEST26['SCORE'], y_pred=pred)

# %%
mse
# Out:
# 21.632757503003138

# %% [markdown]
# # Q3 Answer

# %%
print(round(mse, 3))
# Out:
# 21.633
